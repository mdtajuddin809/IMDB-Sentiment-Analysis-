# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import load_model

# %%
word_index = imdb.get_word_index()
reverse_word_index = {value: key for key, value in word_index.items()}

# %%
model = load_model('simple_rnn_imdb.h5')
model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (32, 500, 32)          │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (32, 128)              │        20,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (32, 1)                │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 340,739 (1.30 MB)
#  Trainable params: 340,737 (1.30 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
model.get_weights()
# Out:
# [array([[ 0.01527959,  0.12639453,  0.08006055, ..., -0.06565162,
#           0.05597432, -0.02041758],
#         [-0.00984145,  0.00067631,  0.03897398, ..., -0.04115668,
#          -0.01249979,  0.04684751],
#         [-0.14960605, -0.01488463, -0.13594203, ..., -0.1160202 ,
#           0.05582636, -0.14125858],
#         ...,
#         [-0.02287164,  0.04215059, -0.03728983, ..., -0.05834697,
#          -0.11150021,  0.01045167],
#         [ 0.06674422, -0.06841618, -0.04488032, ...,  0.15561537,
#          -0.08900745, -0.03530924],
#         [-0.0928785 , -0.01902057, -0.0244715 , ..., -0.04340631,
#           0.10671447,  0.08961351]], dtype=float32),
#  array([[-0.09634276, -0.09362766, -0.03975176, ..., -0.02865626,
#           0.00993646, -0.17764615],
#         [-0.13730499, -0.19997391,  0.05575482, ..., -0.24827202,
#          -0.07188407,  0.11865358],
#         [ 0.08060836, -0.05428534, -0.07078768, ..., -0.1538135 ,
#           0.18608892, -0.30270278],
#         ...,
#         [ 0.04424827, -0.01948167, -0.21600387, ..., -0.00997192,
#          -0.0344563 , -0.00925762],
#         [ 0.09366856,  0.14731918, -0.01267249, ...,  0.23176166,
#           0.10185994, -0.03987213],
#         [ 0.15276498,  0.05876414, -0.01670807, ...,  0.03944309,
#           0.07277189, -0.29684472]], dtype=float32),
#  array([[-0.05109754, -0.11317931, -0.07802127, ...,  0.0360131 ,
#          -0.11161357, -0.033737  ],
#         [ 0.02038409,  0.01561392,  0.14365686, ..., -0.02559584,
#           0.07645278,  0.01004648],
#         [ 0.00479804, -0.04824508,  0.02858384, ...,  0.09930227,
#          -0.16549104, -0.00756078],
#         ...,
#         [ 0.04634602, -0.03709871,  0.07671128, ..., -0.03329053,
#          -0.10847351,  0.07665483],
#         [ 0.02397024,  0.0609817 ,  0.06325753, ...,  0.00508409,
#           0.0674084 , -0.09684675],
#         [ 0.0739129 ,  0.02551363, -0.29013026, ..., -0.12773502,
#          -0.06151215,  0.08823638]], dtype=float32),
#  array([-0.0454179 ,  0.00099934,  0.02908658,  0.04452741, -0.00950175,
#         -0.02385149, -0.01601691,  0.0394675 ,  0.05322456, -0.02594719,
#         -0.02169691, -0.05115566, -0.03357089, -0.01598942, -0.01558219,
#         -0.03140368, -0.00067895,  0.00948523, -0.00218574, -0.03003885,
#         -0.02931306, -0.02136621, -0.01582015, -0.01312368, -0.01327695,
#         -0.00586431, -0.00270425, -0.0225701 , -0.00350813,  0.05068845,
#         -0.06683648, -0.03153334, -0.01432646, -0.01377756,  0.10560101,
#         -0.00174735, -0.00352176, -0.00858915,  0.00646599,  0.00175273,
#         -0.00351858, -0.07082919,  0.00738964, -0.0385536 , -0.00133151,
#          0.00738293, -0.01584877, -0.00277626,  0.03698726, -0.01321513,
#         -0.03339914, -0.02874377,  0.02885367, -0.01366351, -0.03471614,
#         -0.03262841,  0.01995004, -0.00033972,  0.00607113, -0.02377269,
#          0.01570506,  0.00038688, -0.02794767, -0.04471834, -0.03385016,
#          0.03198075, -0.02012432,  0.03948824,  0.0287476 ,  0.0067024 ,
#         -0.01917586, -0.0240282 , -0.01017965, -0.05710926,  0.02876445,
#         -0.03673945,  0.02309074, -0.01706887,  0.02470014, -0.03299589,
#         -0.05129466, -0.002007  , -0.04430936,  0.00243841,  0.02805375,
#         -0.05213725,  0.01780753, -0.02547907,  0.01076122,  0.00607885,
#          0.04044071, -0.00384419, -0.0367916 , -0.01659248,  0.02023447,
#          0.04489001,  0.03481443,  0.01545416, -0.0018582 , -0.01124437,
#         -0.04114438, -0.03697614,  0.027393  , -0.04072734,  0.00727731,
#          0.01874688, -0.01743111,  0.02528638, -0.03282399, -0.01047169,
#         -0.02927568, -0.00209087,  0.02031358,  0.01036425,  0.00569069,
#          0.02296071, -0.03258839,  0.01536399,  0.01016631,  0.04667063,
#         -0.04875034,  0.02577118, -0.01943345,  0.05066143,  0.00461331,
#         -0.00450392,  0.0031774 ,  0.02995531], dtype=float32),
#  array([[ 0.1239403 ],
#         [-0.21722299],
#         [ 0.03903887],
#         [-0.04575849],
#         [ 0.161938  ],
#         [ 0.04259162],
#         [ 0.19005075],
#         [-0.08989487],
#         [-0.15783711],
#         [-0.14890777],
#         [-0.08807687],
#         [-0.0670812 ],
#         [-0.0859461 ],
#         [-0.06477326],
#         [-0.18247819],
#         [-0.09647793],
#         [-0.04078702],
#         [-0.20599943],
#         [ 0.07545388],
#         [-0.08415263],
#         [ 0.30506057],
#         [ 0.10384328],
#         [-0.23184237],
#         [-0.07022628],
#         [-0.24878046],
#         [-0.17348923],
#         [ 0.06133326],
#         [ 0.05005873],
#         [-0.04008477],
#         [ 0.01094005],
#         [-0.41967225],
#         [-0.10175265],
#         [-0.08452419],
#         [-0.17426318],
#         [-0.10857484],
#         [-0.25732708],
#         [-0.10941499],
#         [-0.13727176],
#         [-0.11864328],
#         [-0.2398603 ],
#         [-0.20962334],
#         [-0.03399982],
#         [-0.26540262],
#         [-0.2021588 ],
#         [ 0.02242972],
#         [-0.06671074],
#         [-0.0164119 ],
#         [ 0.11131217],
#         [ 0.09652299],
#         [-0.20712571],
#         [ 0.02451316],
#         [-0.04069923],
#         [-0.22425754],
#         [-0.25086644],
#         [ 0.10161729],
#         [ 0.21960835],
#         [-0.1365226 ],
#         [ 0.20710018],
#         [ 0.12799695],
#         [-0.16732234],
#         [ 0.18374237],
#         [ 0.04774863],
#         [-0.17586038],
#         [ 0.11405177],
#         [ 0.7872252 ],
#         [ 0.17550412],
#         [-0.03420419],
#         [-0.1912797 ],
#         [-0.42486456],
#         [-0.18282472],
#         [ 0.02355535],
#         [-0.03109871],
#         [ 0.13983443],
#         [ 0.06905459],
#         [ 0.13840002],
#         [ 0.07900512],
#         [-0.32919085],
#         [ 0.15768678],
#         [ 0.20906465],
#         [ 0.09764646],
#         [-0.11377358],
#         [-0.03127996],
#         [ 0.19316041],
#         [ 0.10993177],
#         [ 0.22521518],
#         [-0.04390228],
#         [-0.18378803],
#         [-0.15240258],
#         [-0.07891697],
#         [-0.11480673],
#         [-0.23949078],
#         [-0.24671717],
#         [-0.14498499],
#         [-0.27714172],
#         [-0.30003387],
#         [ 0.12269598],
#         [-0.32232794],
#         [-0.12609877],
#         [-0.25567472],
#         [ 0.06758625],
#         [-0.12669724],
#         [ 0.15243329],
#         [-0.12228335],
#         [ 0.00429618],
#         [ 0.20031877],
#         [ 0.0151441 ],
#         [-0.23349464],
#         [-0.12991357],
#         [ 0.01928831],
#         [ 0.1215435 ],
#         [-0.20760702],
#         [-0.20692177],
#         [-0.48152238],
#         [-0.27520013],
#         [ 0.25666296],
#         [ 0.15950388],
#         [-0.1524351 ],
#         [ 0.1869898 ],
#         [-0.05107537],
#         [-0.20698781],
#         [ 0.06437005],
#         [-0.05379627],
#         [-0.22350556],
#         [-0.29287347],
#         [ 0.07633323],
#         [-0.1308394 ],
#         [-0.03697108],
#         [-0.12251441]], dtype=float32),
#  array([-0.7094717], dtype=float32)]

# %%
def decode_review(encoded_review):
    return ' '.join([reverse_word_index.get(i - 3, '?') for i in encoded_review])

def preprocess_text(text):
    words = text.lower().split()
    encoded_review = [word_index.get(word, 2 ) + 3 for word in words]
    padded_review = sequence.pad_sequences([encoded_review], maxlen=500)
    return padded_review

# %%
def predict_sentiment(review):
    preprocessed_input= preprocess_text(review)

    prediction = model.predict(preprocessed_input)
    sentiment = 'Positive' if prediction[0][0] >=0.5 else 'Negative'

    return sentiment, prediction[0][0]

# %%
example_review = "This movie was fantastic! I really enjoyed it."

sentiment, score = predict_sentiment(example_review)
print(f"Review: {example_review}")
print(f'Sentiment: {sentiment}')
print(f"Prediction Score :{score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Review: This movie was fantastic! I really enjoyed it.
# Sentiment: Positive
# Prediction Score :0.8237072229385376

# %%
example_review = "The story was predictable and lacked originality. "

sentiment, score = predict_sentiment(example_review)
print(f"Review: {example_review}")
print(f'Sentiment: {sentiment}')
print(f"Prediction Score :{score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Review: The story was predictable and lacked originality.
# Sentiment: Negative
# Prediction Score :0.24967631697654724
